# %%
import pandas as pd
from tenacity import retry, wait_random_exponential, stop_after_attempt
import logging
import json
from tqdm.auto import tqdm

# %%
import os
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
# import openai
# openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# new api
from openai import OpenAI
from openai import OpenAIError

client = OpenAI(
  api_key=os.getenv('OPENAI_API_KEY'),  # this is also the default, it can be omitted
)

# %%
raw_preds = pd.read_csv("../submissions/multibert_ukru_lingua_00_ot_stoprows4_n.csv", converters={"locations": eval})
df_test = pd.read_csv("../data/nlp-ua-locations-extractions/test.csv")
raw_preds['text'] = df_test['text']

# %%
system_message = """
You are a professional datasets labelist. Your job is labeling datasets for further usage in machine learning tasks. Now you are working on the dataset for NER task, which focuses on location extraction. 
You will be given a couple of text samples in Ukrainian and Russian languages along with the set of possible location entities in them. Your task is to inspect each suggested entity and make a verdict on whether it's a valid location entity in the given context or not and explain your decision.  
""" 

user_message_example = """
Text: "РОЗШУКУЮТЬСЯ власники песика зображеного на фото який близько 1-2 тижнів перебуває на території Дарницького району (Бориспільська, 9, корпус 54, територія колишнього радіозаводу)

🐶можливо хтось впізнає свого домашнього улюбленця та забере додому🏠

🟥Характерні ознаки песика:
- колір чорно-коричневий;
- ошейник зеленого кольору (хакі);
-хвостик на кінчику зі стрижкою.

☝🏻Звернутися можна до мешканців багатоквартирного будинку за адресою Бориспільська, 9, які його тут бачать щодня. 
У випадку  якщо впізнали песика та не знаєте де знаходиться територія телефонуйте за номером 0932626376."
Entities: ['Дарницького району', 'Бориспільська, 9', 'корпус 54', 'Бориспільська, 9']
"""

assisstant_message_example = """
[[
    {
        'entity': 'Дарницького району'
        'valid': "YES",
        'explanation': "Refers to the district of city in which a puppy was lost"
    },
    {
        'entity': 'Бориспільська, 9'
        'valid': "NO",
        'explanation': "only part of the full address 'Бориспільська, 9, корпус 54' which is given in the text"
    },
    {
        'entity': 'корпус 54'
        'valid': "NO",
        'explanation': "only part of the full address 'Бориспільська, 9, корпус 54' which is given in the text"
    },
    {
        'entity': 'Бориспільська, 9'
        'valid': "YES",
        'explanation': "address of the mentioned citizen, it's a complete one in the context"
    }
]] 
"""

def user_message(text, entities):
    return f"""
    Text: "{text}"
    Entities: {entities} 
    """

# %%
def generate_functions() -> list:
    return [
        {
            "name": "extract_entities",
            "description": "Select valid entities from the full explanations",
            "type": "object",
            "parameters": {
                "type": "object",
                "properties": {
                    "entities": {
                        "description": "entities reports",
                        "type": "array",
                        "items": {
                            "type": "object",
                                "properties": {
                                    "entity": {
                                        "type": "string"
                                    },
                                    "valid": {
                                        "type": "string"
                                    },
                                    "explanation": {
                                        "type": "string"
                                    }
                                }
                        }
                    }
                }
            },
        }
    ]

# %%
def extract_entities(entities):
    res = []
    for entity in entities:
        if entity['valid'] == "YES":
            res.append(entity['entity'])
        
    return res

# %%
# @retry(wait=wait_random_exponential(min=1, max=4), stop=stop_after_attempt(2))
def run_openai_task(text, entities):
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message_example},
        {"role": "assistant", "content": assisstant_message_example},
        {"role": "user", "content": user_message(text=text, entities=entities)}
    ]

    try:
        response = client.chat.completions.create(
            model="gpt-3.5-turbo-0613",
            messages=messages,
            functions=generate_functions(),
            function_call={"name": "extract_entities"}, 
            temperature=0,
            frequency_penalty=0,
            presence_penalty=0,
        )

        response_message = response.choices[0].message

        available_functions = {"extract_entities": extract_entities}  
        function_name = response_message.function_call.name

        function_to_call = available_functions[function_name]
        logging.info(f"function_to_call: {function_to_call}")

        function_args = json.loads(response_message.function_call.arguments)['entities']
        logging.info(f"function_args: {function_args}")

        function_response = function_to_call(function_args)
        response = response.model_dump()
    except Exception as error:
        print(error)
        function_response = entities
        response = {"error": error}

    return {"model_response": response,
            "function_response": function_response}

# %%
locations = []
responses = []

for i, row in tqdm(raw_preds.iterrows(), total=len(raw_preds)):
    if len(row['locations']) == 0:
        locations.append([])
        responses.append({})
        continue

    res = run_openai_task(text=row['text'], entities=row['locations'])

    locations.append(res['function_response'])
    responses.append(res['model_response'])
# Out:
#   0%|          | 0/477 [00:00<?, ?it/s]
# Expecting value: line 29 column 17 (char 477)
# Expecting value: line 9 column 17 (char 170)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_transports/default.py:66, in map_httpcore_exceptions()
#      65 try:
# ---> 66     yield
#      67 except Exception as exc:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_backends/sync.py:124, in SyncStream.read(self, max_bytes, timeout)
#     123 exc_map: ExceptionMapping = {socket.timeout: ReadTimeout, OSError: ReadError}
# --> 124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ReadTimeout: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_transports/default.py:227, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
# --> 227 with map_httpcore_exceptions():
#     228     resp = self._pool.handle_request(req)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_transports/default.py:83, in map_httpcore_exceptions()
#      82 message = str(exc)
# ---> 83 raise mapped_exc(message) from exc
#
# ReadTimeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/evgeniy/programming/projects/NLP UA Locations Extractions/notebooks/openai_threshold.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a>     responses.append({})
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a>     continue
# ---> <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=9'>10</a> res = run_openai_task(text=row['text'], entities=row['locations'])
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=11'>12</a> locations.append(res['function_response'])
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=12'>13</a> responses.append(res['model_response'])
#
# /home/evgeniy/programming/projects/NLP UA Locations Extractions/notebooks/openai_threshold.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a> messages = [
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=3'>4</a>     {"role": "system", "content": system_message},
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=4'>5</a>     {"role": "user", "content": user_message_example},
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=5'>6</a>     {"role": "assistant", "content": assisstant_message_example},
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=6'>7</a>     {"role": "user", "content": user_message(text=text, entities=entities)}
#       <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=7'>8</a> ]
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=9'>10</a> try:
# ---> <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=10'>11</a>     response = client.chat.completions.create(
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=11'>12</a>         model="gpt-3.5-turbo-0613",
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=12'>13</a>         messages=messages,
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=13'>14</a>         functions=generate_functions(),
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=14'>15</a>         function_call={"name": "extract_entities"},
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=15'>16</a>         temperature=0,
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=16'>17</a>         frequency_penalty=0,
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=17'>18</a>         presence_penalty=0,
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=18'>19</a>     )
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=20'>21</a>     response_message = response.choices[0].message
#      <a href='vscode-notebook-cell:/home/evgeniy/programming/projects/NLP%20UA%20Locations%20Extractions/notebooks/openai_threshold.ipynb#X56sZmlsZQ%3D%3D?line=22'>23</a>     available_functions = {"extract_entities": extract_entities}
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_utils/_utils.py:299, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297             msg = f"Missing required argument: {quote(missing[0])}"
#     298     raise TypeError(msg)
# --> 299 return func(*args, **kwargs)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/resources/chat/completions.py:594, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     592     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     593 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 594     return self._post(
#     595         "/chat/completions",
#     596         body=maybe_transform(
#     597             {
#     598                 "messages": messages,
#     599                 "model": model,
#     600                 "frequency_penalty": frequency_penalty,
#     601                 "function_call": function_call,
#     602                 "functions": functions,
#     603                 "logit_bias": logit_bias,
#     604                 "max_tokens": max_tokens,
#     605                 "n": n,
#     606                 "presence_penalty": presence_penalty,
#     607                 "response_format": response_format,
#     608                 "seed": seed,
#     609                 "stop": stop,
#     610                 "stream": stream,
#     611                 "temperature": temperature,
#     612                 "tool_choice": tool_choice,
#     613                 "tools": tools,
#     614                 "top_p": top_p,
#     615                 "user": user,
#     616             },
#     617             completion_create_params.CompletionCreateParams,
#     618         ),
#     619         options=make_request_options(
#     620             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     621         ),
#     622         cast_to=ChatCompletion,
#     623         stream=stream or False,
#     624         stream_cls=Stream[ChatCompletionChunk],
#     625     )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_base_client.py:1055, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1041 def post(
#    1042     self,
#    1043     path: str,
#    (...)
#    1050     stream_cls: type[_StreamT] | None = None,
#    1051 ) -> ResponseT | _StreamT:
#    1052     opts = FinalRequestOptions.construct(
#    1053         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1054     )
# -> 1055     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_base_client.py:834, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     825 def request(
#     826     self,
#     827     cast_to: Type[ResponseT],
#    (...)
#     832     stream_cls: type[_StreamT] | None = None,
#     833 ) -> ResponseT | _StreamT:
# --> 834     return self._request(
#     835         cast_to=cast_to,
#     836         options=options,
#     837         stream=stream,
#     838         stream_cls=stream_cls,
#     839         remaining_retries=remaining_retries,
#     840     )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_base_client.py:880, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     878 except httpx.TimeoutException as err:
#     879     if retries > 0:
# --> 880         return self._retry_request(
#     881             options,
#     882             cast_to,
#     883             retries,
#     884             stream=stream,
#     885             stream_cls=stream_cls,
#     886         )
#     887     raise APITimeoutError(request=request) from err
#     888 except Exception as err:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_base_client.py:925, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     921 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     922 # different thread if necessary.
#     923 time.sleep(timeout)
# --> 925 return self._request(
#     926     options=options,
#     927     cast_to=cast_to,
#     928     remaining_retries=remaining,
#     929     stream=stream,
#     930     stream_cls=stream_cls,
#     931 )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/openai/_base_client.py:858, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     855 self._prepare_request(request)
#     857 try:
# --> 858     response = self._client.send(request, auth=self.custom_auth, stream=stream)
#     859     log.debug(
#     860         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     861     )
#     862     response.raise_for_status()
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:901, in Client.send(self, request, stream, auth, follow_redirects)
#     893 follow_redirects = (
#     894     self.follow_redirects
#     895     if isinstance(follow_redirects, UseClientDefault)
#     896     else follow_redirects
#     897 )
#     899 auth = self._build_request_auth(request, auth)
# --> 901 response = self._send_handling_auth(
#     902     request,
#     903     auth=auth,
#     904     follow_redirects=follow_redirects,
#     905     history=[],
#     906 )
#     907 try:
#     908     if not stream:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:929, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     926 request = next(auth_flow)
#     928 while True:
# --> 929     response = self._send_handling_redirects(
#     930         request,
#     931         follow_redirects=follow_redirects,
#     932         history=history,
#     933     )
#     934     try:
#     935         try:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:966, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     963 for hook in self._event_hooks["request"]:
#     964     hook(request)
# --> 966 response = self._send_single_request(request)
#     967 try:
#     968     for hook in self._event_hooks["response"]:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_client.py:1002, in Client._send_single_request(self, request)
#     997     raise RuntimeError(
#     998         "Attempted to send an async request with a sync Client instance."
#     999     )
#    1001 with request_context(request=request):
# -> 1002     response = transport.handle_request(request)
#    1004 assert isinstance(response.stream, SyncByteStream)
#    1006 response.request = request
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpx/_transports/default.py:228, in HTTPTransport.handle_request(self, request)
#     215 req = httpcore.Request(
#     216     method=request.method,
#     217     url=httpcore.URL(
#    (...)
#     225     extensions=request.extensions,
#     226 )
#     227 with map_httpcore_exceptions():
# --> 228     resp = self._pool.handle_request(req)
#     230 assert isinstance(resp.stream, typing.Iterable)
#     232 return Response(
#     233     status_code=resp.status,
#     234     headers=resp.headers,
#     235     stream=ResponseStream(resp.stream),
#     236     extensions=resp.extensions,
#     237 )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1292     if flags != 0:
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#    1298     return super().recv(buflen, flags)
#
# File ~/.local/bin/miniconda3/envs/nlp-env/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1167         return self._sslobj.read(len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#    1171     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
len(locations)
# Out:
# 433

# %%
locations[432]
# Out:
# ['Асканія-Нова', 'Херсонській області', 'парку "Асканії-Нової"']

# %%
locations += raw_preds.loc[433:, 'locations'].to_list()

# %%
len(locations)
# Out:
# 477

# %%
raw_preds['locations_new'] = locations

# %%
raw_preds.to_csv("../submissions/gpt_corrections_091.csv", index=None)

# %%
from json.decoder import JSONDecodeError

# %%
responses_fixed = []
for resp in responses:
    if 'error' in resp and type(resp['error']) == JSONDecodeError:
        responses_fixed.append({'error': str(resp['error'])})
    else:
        responses_fixed.append(resp)

# %%
json.dump(responses_fixed, fp=open('reponses.json', 'w'))

# %%
raw_preds
# Out:
#      text_id                                          locations  \
# 0          0                                                 []
# 1          1     [Києві, Шулявського шляхопроводу, Шулявського]
# 2          2  [Гоголеве, Миргородського району, Полтавської ...
# 3          3                                                 []
# 4          4                  [проспекті Академіка Глушкова, 9]
# ..       ...                                                ...
# 472      472  [Київщини, Україні, Київської області, Бучансь...
# 473      473                                            [Землі]
# 474      474                                                 []
# 475      475                            [Києві, Дніпра, Дніпро]
# 476      476                                            [Києві]
#
#                                                   text  \
# 0    ❗️Кількість поранених зросла до трьох, – Кличк...
# 1    🥤В Києві за 91,13 млн гривень починаються робо...
# 2    ▪️Сьогодні вночі росіяни завдали ракетного уда...
# 3    Наразі у запасах росіян найбільше балістичних ...
# 4    ⛸В один день, 29 серпня, ДП "Центральна учбово...
# ..                                                 ...
# 472  Допомога на відновлення: п’ять громад Київщини...
# 473  Пророцтво Стругацьких: незвичайна бактерія Бра...
# 474  Із 1 вересня УГКЦ і ПЦУ перейшли на новий церк...
# 475  🦇 У Києві з Дніпра виловили іноземця в масці Б...
# 476  У Києві виявили парковку з машинами на мільйон...
#
#                                          locations_new
# 0                                                   []
# 1                    [Києві, Шулявського шляхопроводу]
# 2    [Гоголеве, Миргородського району, Полтавської ...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 472  [Київщини, Україні, Київської області, Бучансь...
# 473                                            [Землі]
# 474                                                 []
# 475                            [Києві, Дніпра, Дніпро]
# 476                                            [Києві]
#
# [477 rows x 4 columns]

# %%
best_preds = pd.read_csv("../submissions/multibert_ukru_lingua_0906_ot_stoprows4_n.csv")

# %%
best_preds.loc[:433, 'locations'] = raw_preds.loc[:433, "locations_new"]

# %%
best_preds.to_csv("../submissions/multibert_ukru_lingua_0906_ot_stoprows4_n_gpt091.csv", index=None)

# %% [markdown]
# ## Review responses

# %%
responses = json.load(open("reponses.json"))

# %%
resps = []
for resp in responses:
    if 'choices' in resp:
        resps.append(resp['choices'][0]['message']['function_call']['arguments'])

# %%
for resp in resps:
    print(resp)
# Out:
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, mentioned in the text"
#     },
#     {
#       "entity": "Шулявського шляхопроводу",
#       "valid": "YES",
#       "explanation": "Refers to the Shuliavskyi Overpass, which is mentioned in the text as a location for reconstruction"
#     },
#     {
#       "entity": "Шулявського",
#       "valid": "NO",
#       "explanation": "The entity 'Шулявського' is not a complete location entity and does not provide enough information to identify a specific location"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Гоголеве",
#       "valid": "YES",
#       "explanation": "Refers to the village that was targeted by the missile strike"
#     },
#     {
#       "entity": "Миргородського району",
#       "valid": "YES",
#       "explanation": "Refers to the district where the village of Gogoleve is located"
#     },
#     {
#       "entity": "Полтавської області",
#       "valid": "YES",
#       "explanation": "Refers to the region where the district of Mirgorod is located"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "проспекті Академіка Глушкова, 9",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Броварах",
#       "valid": "YES",
#       "explanation": "Refers to the location where the industrial park is planned to be created"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Псков",
#       "valid": "YES",
#       "explanation": "Refers to a location mentioned in the text"
#     },
#     {
#       "entity": "Брянськ",
#       "valid": "YES",
#       "explanation": "Refers to a location mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Забуччя",
#       "valid": "YES",
#       "explanation": "Refers to the name of the village where the fire incident occurred"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Солом’янському районі столиці",
#       "valid": "YES",
#       "explanation": "Refers to the Solom’ianskyi district of the capital city"
#     },
#     {
#       "entity": "вулиці Новій",
#       "valid": "YES",
#       "explanation": "Refers to a street named 'Novyi' in the context of the Solom’ianskyi district"
#     },
#     {
#       "entity": "Солом’янському районі",
#       "valid": "YES",
#       "explanation": "Refers to the Solom’ianskyi district"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Левка Лукʼяненка, 3",
#       "valid": "YES",
#       "explanation": "Refers to the address where the fire incident occurred"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Варшави",
#       "valid": "YES",
#       "explanation": "Refers to the city of Warsaw, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Білоцерківській громаді",
#       "valid": "YES",
#       "explanation": "Refers to a specific community or municipality in Bilohirsk"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "аеродрому \"Оленья\"",
#       "valid": "YES",
#       "explanation": "Refers to the specific airport mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city where the farewell ceremony is taking place"
#     },
#     {
#       "entity": "Патріаршому соборі Воскресіння Христового УГКЦ",
#       "valid": "YES",
#       "explanation": "Refers to the specific location where the farewell ceremony is taking place"
#     },
#     {
#       "entity": "Житомирщині",
#       "valid": "YES",
#       "explanation": "Refers to the region where the plane crash occurred"
#     },
#     {
#       "entity": "РФ",
#       "valid": "NO",
#       "explanation": "Refers to the abbreviation of the Russian Federation, which is not a specific location mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дарницькому районі столиці",
#       "valid": "YES",
#       "explanation": "Refers to the location of the incident in the Darnytskyi district of the capital city"
#     },
#     {
#       "entity": "Дарницькому районі",
#       "valid": "YES",
#       "explanation": "Refers to the location of the incident in the Darnytskyi district"
#     },
#     {
#       "entity": "Ашан",
#       "valid": "NO",
#       "explanation": "Refers to a specific store chain, not a location"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Лісовий проспект 6-14",
#       "valid": "",
#       "explanation": ""
#     },
#     {
#       "entity": "Поверну",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv"
#     },
#     {
#       "entity": "вулицю Нову",
#       "valid": "YES",
#       "explanation": "Refers to a street named 'Нова' in Kyiv"
#     },
#     {
#       "entity": "Солом’янському районі",
#       "valid": "YES",
#       "explanation": "Refers to the Solomianskyi district in Kyiv"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country where the pilot surrendered"
#     },
#     {
#       "entity": "Україна",
#       "valid": "YES",
#       "explanation": "Refers to the country where the pilot surrendered"
#     },
#     {
#       "entity": "Харківщини",
#       "valid": "YES",
#       "explanation": "Refers to the region where the operation took place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Шевченківському районі Києва",
#       "valid": "YES",
#       "explanation": "Refers to the district in Kyiv where the fire incident occurred"
#     },
#     {
#       "entity": "Загоряння",
#       "valid": "YES",
#       "explanation": "Refers to the fire incident that took place"
#     },
#     {
#       "entity": "вул. Димитрівська, 4",
#       "valid": "YES",
#       "explanation": "Refers to the specific address where the fire incident occurred"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Героїв Дніпра, 43",
#       "valid": "",
#       "explanation": ""
#     },
#     {
#       "entity": "Київ",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Криму",
#       "valid": "YES",
#       "explanation": "Refers to the region of Crimea, which is mentioned in the text"
#     },
#     {
#       "entity": "Подоляк",
#       "valid": "NO",
#       "explanation": "No context provided for this entity"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country of Ukraine, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дмитровской",
#       "valid": "YES",
#       "explanation": "Refers to a specific location mentioned in the text, likely a street or area"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Братського Богоявленського монастиря",
#       "valid": "YES",
#       "explanation": "Refers to the mentioned monument, which is the former Bratsky Bogoyavlensky Monastery"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дмитриевская",
#       "valid": "YES",
#       "explanation": "Refers to a street name mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Шевченківський район",
#       "valid": "YES",
#       "explanation": "Refers to a specific district mentioned in the text where the medics were called to"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Новій Каховці",
#       "valid": "YES",
#       "explanation": "Refers to the location where the regional campaign headquarters of 'Єдина Росія' was bombed"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дарницькому районі",
#       "valid": "YES",
#       "explanation": "Refers to the district in which the fire and rescue services are working"
#     },
#     {
#       "entity": "Шевченківському районі столиці",
#       "valid": "YES",
#       "explanation": "Refers to the district in which the fire and rescue services are working"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city where the rocket attack occurred"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "вулиці Гоголівська",
#       "valid": "YES",
#       "explanation": "Refers to a street name in the city"
#     },
#     {
#       "entity": "вулицю Шевченківська",
#       "valid": "YES",
#       "explanation": "Refers to a proposed new street name in the city"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region surrounding the city of Kyiv"
#     },
#     {
#       "entity": "Білоцерківському районі",
#       "valid": "YES",
#       "explanation": "Refers to the district in which the controlled explosions will take place"
#     },
#     {
#       "entity": "Київ",
#       "valid": "NO",
#       "explanation": "Refers to the city itself, not the surrounding region"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "вул. Князів Острозьких",
#       "valid": "YES",
#       "explanation": "Refers to a street name mentioned in the text"
#     },
#     {
#       "entity": "№25",
#       "valid": "YES",
#       "explanation": "Refers to a bus route number mentioned in the text"
#     },
#     {
#       "entity": "62",
#       "valid": "YES",
#       "explanation": "Refers to a bus route number mentioned in the text"
#     },
#     {
#       "entity": "№38",
#       "valid": "YES",
#       "explanation": "Refers to a trolleybus route number mentioned in the text"
#     },
#     {
#       "entity": "№ 38",
#       "valid": "YES",
#       "explanation": "Refers to a temporary bus route number mentioned in the text"
#     },
#     {
#       "entity": "ТР",
#       "valid": "NO",
#       "explanation": "The context does not provide enough information to determine the meaning of 'ТР'"
#     },
#     {
#       "entity": "№470",
#       "valid": "YES",
#       "explanation": "Refers to a minibus route number mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, mentioned in the context"
#     },
#     {
#       "entity": "аеропорт",
#       "valid": "YES",
#       "explanation": "Refers to the airport, specifically mentioned 'аеропорт \"Донецьк\"'"
#     },
#     {
#       "entity": "Донецьк",
#       "valid": "YES",
#       "explanation": "Refers to the city Donetsk, mentioned in the context"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, mentioned in the context"
#     },
#     {
#       "entity": "Донецького аеропорту",
#       "valid": "YES",
#       "explanation": "Refers to the Donetsk airport, mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Привида Києва",
#       "valid": "NO",
#       "explanation": "Refers to a fictional character 'Ghost of Kyiv', not a valid location entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дарницькому районі",
#       "valid": "YES",
#       "explanation": "Refers to the district where the incident of debris falling on the roof of a commercial building occurred."
#     },
#     {
#       "entity": "Шевченківському",
#       "valid": "YES",
#       "explanation": "Refers to the district where the incident of debris falling occurred."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text as the starting and ending point of the train journey."
#     },
#     {
#       "entity": "Хелм",
#       "valid": "YES",
#       "explanation": "Refers to the destination of the new international train mentioned in the text."
#     },
#     {
#       "entity": "Хелма",
#       "valid": "NO",
#       "explanation": "The entity 'Хелма' is not mentioned in the text."
#     },
#     {
#       "entity": "Варшави",
#       "valid": "YES",
#       "explanation": "Refers to the city of Warsaw, which is mentioned as a transfer point for the train journey."
#     },
#     {
#       "entity": "IC12100",
#       "valid": "NO",
#       "explanation": "The entity 'IC12100' is not explained in the text and its meaning is unclear."
#     },
#     {
#       "entity": "Варшава Всходня",
#       "valid": "NO",
#       "explanation": "The entity 'Варшава Всходня' is not mentioned in the text."
#     },
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the destination of the return journey mentioned in the text."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Експоцентру",
#       "valid": "YES",
#       "explanation": "Refers to the location of the matcha-bar DOT 2.0, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Великобританії",
#       "valid": "YES",
#       "explanation": "Refers to the country from which the volunteer originated"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country where the volunteer died"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country where the volunteer died"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country where the volunteer died"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Суперблакитним місяцем",
#       "valid": "YES",
#       "explanation": "Refers to the rare event of a Super Blue Moon"
#     },
#     {
#       "entity": "Супермісяця",
#       "valid": "YES",
#       "explanation": "Refers to the event of a Supermoon"
#     },
#     {
#       "entity": "Мексиці",
#       "valid": "YES",
#       "explanation": "Refers to the country where the Super Blue Moon was observed"
#     },
#     {
#       "entity": "Каліфорнії",
#       "valid": "YES",
#       "explanation": "Refers to the state where the Super Blue Moon was observed"
#     },
#     {
#       "entity": "Бразилії",
#       "valid": "YES",
#       "explanation": "Refers to the country where the Super Blue Moon was observed"
#     },
#     {
#       "entity": "Туреччині",
#       "valid": "YES",
#       "explanation": "Refers to the country where the Super Blue Moon was observed"
#     },
#     {
#       "entity": "Греції",
#       "valid": "YES",
#       "explanation": "Refers to the country where the Super Blue Moon was observed"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Борщагівці",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, the neighborhood of Borschahivka"
#     },
#     {
#       "entity": "Київраді",
#       "valid": "NO",
#       "explanation": "Refers to the city council of Kyiv, not a specific location"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country of Ukraine, mentioned in the text"
#     },
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Сумщину",
#       "valid": "YES",
#       "explanation": "Refers to the region of Sumy in the context of the movement of rockets"
#     },
#     {
#       "entity": "Чернігівщини",
#       "valid": "YES",
#       "explanation": "Refers to the region of Chernihiv in the context of the movement of rockets"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Голодомор",
#       "valid": "YES",
#       "explanation": "Refers to the historical event of the Ukrainian famine-genocide in 1932-1933"
#     },
#     {
#       "entity": "Голодомор",
#       "valid": "YES",
#       "explanation": "Refers to the historical event of the Ukrainian famine-genocide in 1932-1933"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Лаврі",
#       "valid": "YES",
#       "explanation": "Refers to a location where a new Pope or abbot is being chosen"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Шевченківський райсуд Києва",
#       "valid": "YES",
#       "explanation": "Refers to a specific court in Kyiv where Kolomoisky arrived"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Луганських та Донецьких областей",
#       "valid": "",
#       "explanation": ""
#     },
#     {
#       "entity": "Україні",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Донецької та Херсонської областей",
#       "valid": "YES",
#       "explanation": "Refers to the regions that will receive the most funding"
#     },
#     {
#       "entity": "Чернігівської.",
#       "valid": "YES",
#       "explanation": "Refers to the region that will receive funding"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "вулиці Академіка Білецького",
#       "valid": "YES",
#       "explanation": "Refers to a specific street in Kyiv where the first incident happened"
#     },
#     {
#       "entity": "проспекті Відрадному",
#       "valid": "YES",
#       "explanation": "Refers to a specific avenue in Kyiv where the second incident happened"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Житомира",
#       "valid": "YES",
#       "explanation": "Refers to the city of Zhytomyr, which is mentioned in the text"
#     },
#     {
#       "entity": "Святошинському районі Києва",
#       "valid": "YES",
#       "explanation": "Refers to the district of Kyiv city, which is mentioned in the text"
#     },
#     {
#       "entity": "Житомирському шосе",
#       "valid": "YES",
#       "explanation": "Refers to the highway named Zhytomyrskyi Shose, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Лиманському",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, likely a geographical area or a town, where a battle took place"
#     },
#     {
#       "entity": "Авдіївському",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, likely a geographical area or a town, where a battle took place"
#     },
#     {
#       "entity": "Мар’їнському напрямках",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, likely a geographical area or a town, where a battle took place"
#     },
#     {
#       "entity": "Мелітопольському напрямку",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, likely a geographical area or a town, where a battle took place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "США",
#       "valid": "NO",
#       "explanation": "The mention of the United States (США) is not relevant to the context of the text, which is about a criminal organization in Kyiv, Ukraine."
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is the main location mentioned in the text."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дніпро",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києвом",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv"
#     },
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv"
#     },
#     {
#       "entity": "Хрещатику 36",
#       "valid": "YES",
#       "explanation": "Refers to the specific address on Khreshchatyk street in Kyiv"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv"
#     },
#     {
#       "entity": "Чорнобиль",
#       "valid": "YES",
#       "explanation": "Refers to the city of Chernobyl"
#     },
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv"
#     },
#     {
#       "entity": "Тетерів",
#       "valid": "YES",
#       "explanation": "Refers to the city of Teteriv"
#     },
#     {
#       "entity": "Фастів",
#       "valid": "YES",
#       "explanation": "Refers to the city of Fastiv"
#     },
#     {
#       "entity": "Біла Церква",
#       "valid": "YES",
#       "explanation": "Refers to the city of Bila Tserkva"
#     },
#     {
#       "entity": "Миронівка",
#       "valid": "YES",
#       "explanation": "Refers to the city of Myronivka"
#     },
#     {
#       "entity": "Бориспіль",
#       "valid": "YES",
#       "explanation": "Refers to the city of Boryspil"
#     },
#     {
#       "entity": "Яготин",
#       "valid": "YES",
#       "explanation": "Refers to the city of Yahotyn"
#     },
#     {
#       "entity": "Баришівка",
#       "valid": "YES",
#       "explanation": "Refers to the city of Baryshivka"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city where the rocket attack took place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Подолі",
#       "valid": "YES",
#       "explanation": "Refers to a specific location mentioned in the text, the district of the city"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "будинками №16, 18, 20",
#       "valid": "YES",
#       "explanation": "Refers to the buildings with numbers 16, 18, and 20"
#     },
#     {
#       "entity": "проспекту Володимира Івасюка",
#       "valid": "YES",
#       "explanation": "Refers to the street named Volodymyra Ivasyuka"
#     },
#     {
#       "entity": "вул. Л.Лукʼяненка, 13",
#       "valid": "YES",
#       "explanation": "Refers to the street named L. Lukyanenka with the house number 13"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Охматдиті",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Велику Димерку",
#       "valid": "YES",
#       "explanation": "Refers to the location mentioned in the text, specifically the town of Velika Dymerka"
#     },
#     {
#       "entity": "Велика Димерка",
#       "valid": "YES",
#       "explanation": "Refers to the location mentioned in the text, specifically the town of Velika Dymerka"
#     },
#     {
#       "entity": "Броварщині",
#       "valid": "YES",
#       "explanation": "Refers to the region mentioned in the text, specifically the Brovary region"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Жилянську Непоп",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Андріївському узвозі",
#       "valid": "YES",
#       "explanation": "Refers to the location where the historical building is being demolished"
#     },
#     {
#       "entity": "Андріївському узвозі, 26",
#       "valid": "YES",
#       "explanation": "Refers to the specific address of the historical building"
#     },
#     {
#       "entity": "будинок Тарнавського",
#       "valid": "YES",
#       "explanation": "Refers to the historical building owned by Vsevolod Tarnavsky"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дарницькому районі",
#       "valid": "YES",
#       "explanation": "Refers to the location where the fire is happening"
#     },
#     {
#       "entity": "Шевченківському районі",
#       "valid": "YES",
#       "explanation": "Refers to the location where the fire is happening"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "США",
#       "valid": "NO",
#       "explanation": "The entity 'США' does not refer to a location in the given context. It stands for the United States of America, which is not relevant to the text about the court hearing in Kyiv, Ukraine."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Ірпені",
#       "valid": "YES",
#       "explanation": "Refers to the location where road repairs will take place"
#     },
#     {
#       "entity": "Гостомельського шосе",
#       "valid": "YES",
#       "explanation": "Refers to the road that will be partially closed due to road repairs"
#     },
#     {
#       "entity": "Ірпені",
#       "valid": "NO",
#       "explanation": "Duplicate entity, already mentioned before"
#     },
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region where Ірпені is located"
#     },
#     {
#       "entity": "Котляревського",
#       "valid": "YES",
#       "explanation": "Refers to a street in Ірпені"
#     },
#     {
#       "entity": "Северинівської",
#       "valid": "YES",
#       "explanation": "Refers to a street in Ірпені"
#     },
#     {
#       "entity": "Гостомеля",
#       "valid": "YES",
#       "explanation": "Refers to a location near Ірпені"
#     },
#     {
#       "entity": "Гостомельське шосе",
#       "valid": "YES",
#       "explanation": "Refers to the road that will be partially closed due to road repairs"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country of Ukraine, mentioned in the text"
#     },
#     {
#       "entity": "Охматдиту",
#       "valid": "YES",
#       "explanation": "Refers to the hospital 'Охматдит', mentioned in the text"
#     },
#     {
#       "entity": "Охматдиті",
#       "valid": "NO",
#       "explanation": "Misspelled form of 'Охматдиту', which is already mentioned as a valid entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Киевщине",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Троещине",
#       "valid": "YES",
#       "explanation": "Refers to a specific location where the serial killer is operating"
#     },
#     {
#       "entity": "Драйзера",
#       "valid": "YES",
#       "explanation": "Refers to a specific location where one of the incidents occurred"
#     },
#     {
#       "entity": "Червоной Калины",
#       "valid": "YES",
#       "explanation": "Refers to a specific location where one of the incidents occurred"
#     },
#     {
#       "entity": "Цветаевой",
#       "valid": "YES",
#       "explanation": "Refers to a specific location where one of the incidents occurred"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv where the farewell ceremony took place"
#     },
#     {
#       "entity": "Донбасі",
#       "valid": "YES",
#       "explanation": "Refers to the region where the deputy was killed"
#     },
#     {
#       "entity": "Курдюмівка",
#       "valid": "YES",
#       "explanation": "Refers to the specific location near which the deputy was killed"
#     },
#     {
#       "entity": "Київраді",
#       "valid": "YES",
#       "explanation": "Refers to the Kyiv City Council where the deputy served"
#     },
#     {
#       "entity": "Михайлівському соборі",
#       "valid": "YES",
#       "explanation": "Refers to the St. Michael's Golden-Domed Monastery Cathedral where the farewell took place"
#     },
#     {
#       "entity": "Михайлівського собору",
#       "valid": "YES",
#       "explanation": "Refers to the St. Michael's Golden-Domed Monastery Cathedral where the farewell took place"
#     },
#     {
#       "entity": "Майдану Незалежності",
#       "valid": "YES",
#       "explanation": "Refers to Independence Square where the farewell ceremony took place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Киеве",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv mentioned in the text"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country of Ukraine mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Литві",
#       "valid": "YES",
#       "explanation": "Refers to the country where the video portal was created"
#     },
#     {
#       "entity": "Польщі",
#       "valid": "YES",
#       "explanation": "Refers to the country where the video portal was created"
#     },
#     {
#       "entity": "Вільнюс",
#       "valid": "YES",
#       "explanation": "Refers to the city that is connected to the video portal"
#     },
#     {
#       "entity": "Люблін",
#       "valid": "YES",
#       "explanation": "Refers to the city that is connected to the video portal"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country where the first board game library is opening"
#     },
#     {
#       "entity": "просп. Берестейський, 25-А",
#       "valid": "YES",
#       "explanation": "Complete address of the Central Library named after T. H. Shevchenko for children"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv where the trees were planted"
#     },
#     {
#       "entity": "парку “Прибережний”",
#       "valid": "YES",
#       "explanation": "Refers to the specific park named 'Прибережний' where the trees were planted"
#     },
#     {
#       "entity": "Берковщина",
#       "valid": "NO",
#       "explanation": "Insufficient information to determine if it's a valid location entity"
#     },
#     {
#       "entity": "Запорізькому напрямку",
#       "valid": "YES",
#       "explanation": "Refers to the direction of Zaporizhzhia where the military operation took place"
#     },
#     {
#       "entity": "просп. Леся Курбаса",
#       "valid": "YES",
#       "explanation": "Refers to the avenue named 'просп. Леся Курбаса' where the memorial alley is located"
#     },
#     {
#       "entity": "вул. Героїв Космосу",
#       "valid": "YES",
#       "explanation": "Refers to the street named 'вул. Героїв Космосу' where the memorial alley is located"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Золотих Воріт",
#       "valid": "YES",
#       "explanation": "Refers to a location in Kyiv mentioned in the text"
#     },
#     {
#       "entity": "Рейтарської та Пейзажної алеї",
#       "valid": "YES",
#       "explanation": "Refers to locations in Kyiv mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Петербурзі",
#       "valid": "YES",
#       "explanation": "Refers to the city of Saint Petersburg, which is a valid location entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україна",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Стіні Памʼяті",
#       "valid": "YES",
#       "explanation": "Refers to a specific memorial mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country where the Ministry of Defense is located"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києво-Печерській лаврі",
#       "valid": "YES",
#       "explanation": "Refers to the specific location, Kyiv-Pechersk Lavra, which is mentioned in the text"
#     },
#     {
#       "entity": "Успенський",
#       "valid": "NO",
#       "explanation": "The entity 'Успенський' is not clear whether it refers to a location or a person. More context is needed to determine its validity."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Васильковом",
#       "valid": "YES",
#       "explanation": "Refers to the town of Vasilkov where the suburban trains will be running"
#     },
#     {
#       "entity": "Киевом",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kiev where the suburban trains will be running"
#     },
#     {
#       "entity": "Киев-Пассажирский",
#       "valid": "YES",
#       "explanation": "Refers to the Kiev-Passenger station, which is the departure point for the suburban trains"
#     },
#     {
#       "entity": "Васильков-Центр",
#       "valid": "YES",
#       "explanation": "Refers to the Vasilkov-Center station, which is the arrival point for the suburban trains"
#     },
#     {
#       "entity": "Васильков-Центр",
#       "valid": "NO",
#       "explanation": "Duplicate entity"
#     },
#     {
#       "entity": "Киев-Пассажирский",
#       "valid": "NO",
#       "explanation": "Duplicate entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Юго-Западная",
#       "valid": "YES",
#       "explanation": "Refers to a train station named 'Юго-Западная' which is mentioned in the text"
#     },
#     {
#       "entity": "Киев-Васильков-Киев",
#       "valid": "YES",
#       "explanation": "Refers to the route of the additional suburban trains mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Печерську",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дніпрі",
#       "valid": "YES",
#       "explanation": "Refers to the city where the shooting incident took place"
#     },
#     {
#       "entity": "Дніпра",
#       "valid": "YES",
#       "explanation": "Refers to the city where the shooting incident took place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україну",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the text"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Росію",
#       "valid": "YES",
#       "explanation": "Refers to the country that was attacked by drones"
#     },
#     {
#       "entity": "Крим",
#       "valid": "YES",
#       "explanation": "Refers to the region that was attacked by drones"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Пскові",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Киеве",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Полтавщині",
#       "valid": "YES",
#       "explanation": "Refers to the region of Poltava in Ukraine where the industrial object is located"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україну",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, which is mentioned in the context"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, which is mentioned in the context"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, which is mentioned in the context"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, which is mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Почайна",
#       "valid": "YES",
#       "explanation": "Refers to a metro station mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the location where the consequences of enemy shelling were eliminated"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Пскові",
#       "valid": "YES",
#       "explanation": "Refers to the city of Pskov"
#     },
#     {
#       "entity": "Черехінській військовій базі",
#       "valid": "NO",
#       "explanation": "There is no information provided in the text about the existence or location of a military base in Cherehinsk"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дніпровській набережній",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, the Dnipro river embankment"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Київській області",
#       "valid": "YES",
#       "explanation": "Refers to the Kyiv region, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Вениславский",
#       "valid": "YES",
#       "explanation": "Refers to a person mentioned in the text, likely a politician"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Сырца",
#       "valid": "NO",
#       "explanation": "There is no context or information provided about 'Сырца' in the text. It is not clear what it refers to."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region around Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Білоцерківському районі",
#       "valid": "YES",
#       "explanation": "Refers to the district where the controlled explosions will take place, as mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Софійській площі",
#       "valid": "YES",
#       "explanation": "Refers to the location where the photo exhibition 'Воїни світла' is opened"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "№41д",
#       "valid": "NO",
#       "explanation": "Refers to a bus route number, but it is not a specific location entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дніпро",
#       "valid": "YES",
#       "explanation": "Refers to the river mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country where the 'Сільпо' supermarkets are located"
#     },
#     {
#       "entity": ",7",
#       "valid": "NO",
#       "explanation": "Incomplete address, missing the street name"
#     },
#     {
#       "entity": "Вишгород",
#       "valid": "YES",
#       "explanation": "Refers to a city where one of the 'Сільпо' supermarkets is located"
#     },
#     {
#       "entity": "вул. Набережна,11",
#       "valid": "YES",
#       "explanation": "Complete address of a 'Сільпо' supermarket in Вишгород"
#     },
#     {
#       "entity": "арт",
#       "valid": "NO",
#       "explanation": "Unclear entity, needs more context"
#     },
#     {
#       "entity": "Європи",
#       "valid": "YES",
#       "explanation": "Refers to the European Supermarket Magazine, which listed one of the 'Сільпо' supermarkets as one of the best in Europe"
#     },
#     {
#       "entity": "Вінниця",
#       "valid": "YES",
#       "explanation": "Refers to a city where one of the 'Сільпо' supermarkets is located"
#     },
#     {
#       "entity": "вул. Келецька,121",
#       "valid": "YES",
#       "explanation": "Complete address of a 'Сільпо' supermarket in Вінниця"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Житомирщини",
#       "valid": "YES",
#       "explanation": "Refers to the region of Zhhytomyr in Ukraine"
#     },
#     {
#       "entity": "Київщини",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv in Ukraine"
#     }
#   ]
# }
#
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Сирецького іподрому",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дарницькому районі",
#       "valid": "YES",
#       "explanation": "Refers to the district where a fire is happening"
#     },
#     {
#       "entity": "Шевченківському районі",
#       "valid": "YES",
#       "explanation": "Refers to the district where a fire is happening"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Чорному морі",
#       "valid": "YES",
#       "explanation": "Refers to the Black Sea, which is mentioned in the text as the location where the enemy increased the number of missile carriers"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "вулицею",
#       "valid": "YES",
#       "explanation": "Refers to the street mentioned in the text"
#     },
#     {
#       "entity": "Князів Острозьких",
#       "valid": "YES",
#       "explanation": "Refers to the street name mentioned in the text"
#     },
#     {
#       "entity": "вул. Омеляновича-Павленка",
#       "valid": "YES",
#       "explanation": "Refers to the street name mentioned in the text"
#     },
#     {
#       "entity": "вул. Івана Мазепи",
#       "valid": "YES",
#       "explanation": "Refers to the street name mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Загальці",
#       "valid": "YES",
#       "explanation": "Refers to the village where the ambulatory was rebuilt"
#     },
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region where the village of Загальці is located"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Площі Українських Героїв",
#       "valid": "YES",
#       "explanation": "Refers to a specific location mentioned in the text where a car fire occurred"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv, where the girl went missing"
#     },
#     {
#       "entity": "Бучі",
#       "valid": "YES",
#       "explanation": "Refers to the specific town where the family visited before the girl went missing"
#     },
#     {
#       "entity": "Київщини",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv, where the police units were involved in the search"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the context as the focus of the information campaign"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Голосіївському районі Києва",
#       "valid": "YES",
#       "explanation": "Refers to a specific district in Kyiv where they want to build a tennis center"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Оболонського району",
#       "valid": "YES",
#       "explanation": "Refers to a specific district mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Вінниччиною",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Шевченківському районі",
#       "valid": "YES",
#       "explanation": "Refers to the district where the gas pipeline was damaged"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Шевченківському районі",
#       "valid": "YES",
#       "explanation": "Refers to a specific district in the context of the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the entire country of Ukraine"
#     },
#     {
#       "entity": "Добропарк",
#       "valid": "YES",
#       "explanation": "Refers to a specific location mentioned in the text"
#     },
#     {
#       "entity": "Добропарку",
#       "valid": "NO",
#       "explanation": "The entity 'Добропарку' is not a valid location entity in the given context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "парку «Відрадний»",
#       "valid": "YES",
#       "explanation": "Refers to a specific park named 'Відрадний'"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country 'Україна'"
#     },
#     {
#       "entity": "України",
#       "valid": "NO",
#       "explanation": "Duplicate entity, already mentioned in the previous entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Лос Соломас",
#       "valid": "NO",
#       "explanation": "There is no context provided to determine if 'Лос Соломас' is a valid location entity."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "пл. Калiнiна",
#       "valid": "YES",
#       "explanation": "Refers to a square named after Kalinin"
#     },
#     {
#       "entity": "Майдан",
#       "valid": "YES",
#       "explanation": "Refers to a central square or square in a city"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "",
#       "explanation": ""
#     },
#     {
#       "entity": "Парижі",
#       "valid": "",
#       "explanation": ""
#     },
#     {
#       "entity": "Сан-Франциско",
#       "valid": "",
#       "explanation": ""
#     },
#     {
#       "entity": "Парижі",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "ТРЦ Проспект",
#       "valid": "YES",
#       "explanation": "Refers to a shopping mall named 'Проспект'"
#     },
#     {
#       "entity": "Ашану",
#       "valid": "YES",
#       "explanation": "Refers to a specific store named 'Ашану'"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text as the location where the initiative took place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city where the bookstore is located"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
# ...
#       "explanation": "Refers to the location where the book collection event will take place"
#     },
#     {
#       "entity": "вул. Омеляновича-Павленка",
#       "valid": "YES",
#       "explanation": "Refers to a street name mentioned in the context"
#     },
#     {
#       "entity": "Бутишева провулка",
#       "valid": "YES",
#       "explanation": "Refers to a street name mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Нью-Йорку",
#       "valid": "YES",
#       "explanation": "Refers to the city of New York, mentioned in the context"
#     },
#     {
#       "entity": "Нижній Манхеттен",
#       "valid": "YES",
#       "explanation": "Refers to the Lower Manhattan area, mentioned in the context"
#     },
#     {
#       "entity": "Нью-Йорка",
#       "valid": "YES",
#       "explanation": "Refers to the city of New York, mentioned in the context"
#     },
#     {
#       "entity": "-",
#       "valid": "NO",
#       "explanation": "Not a valid location entity, it's a punctuation mark"
#     },
#     {
#       "entity": "Нижнього Манхеттена",
#       "valid": "YES",
#       "explanation": "Refers to the Lower Manhattan area, mentioned in the context"
#     },
#     {
#       "entity": "Сполучених Штатах",
#       "valid": "YES",
#       "explanation": "Refers to the United States, mentioned in the context"
#     },
#     {
#       "entity": "Нью-Йорка",
#       "valid": "YES",
#       "explanation": "Refers to the city of New York, mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Черкащини",
#       "valid": "YES",
#       "explanation": "Refers to the region of Cherkasy in Ukraine"
#     },
#     {
#       "entity": "Київщини",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv in Ukraine"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the news digest"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the news digest"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the news digest"
#     },
#     {
#       "entity": "України",
#       "valid": "NO",
#       "explanation": "Refers to the country, not a specific location in the given context"
#     },
#     {
#       "entity": "Жилянській",
#       "valid": "YES",
#       "explanation": "Refers to a specific location in Kyiv mentioned in the news digest"
#     },
#     {
#       "entity": "Будинку Уткіна",
#       "valid": "YES",
#       "explanation": "Refers to a specific location in Kyiv mentioned in the news digest"
#     },
#     {
#       "entity": "Дніпровського району",
#       "valid": "YES",
#       "explanation": "Refers to a specific location in Kyiv mentioned in the news digest"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city mentioned in the news digest"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Могилянці",
#       "valid": "YES",
#       "explanation": "Refers to the location where the scholarship program is offered"
#     },
#     {
#       "entity": "Миколаєвом",
#       "valid": "YES",
#       "explanation": "Refers to the location where the person fought"
#     },
#     {
#       "entity": "Лисичанськ",
#       "valid": "YES",
#       "explanation": "Refers to the location that the person's unit defended"
#     },
#     {
#       "entity": "Луганщині",
#       "valid": "YES",
#       "explanation": "Refers to the region where Lysychansk is located"
#     },
#     {
#       "entity": "Бахмутом",
#       "valid": "YES",
#       "explanation": "Refers to the location where the person died"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     },
#     {
#       "entity": "Донбасі",
#       "valid": "YES",
#       "explanation": "Refers to the region where the war is taking place, mentioned in the text"
#     },
#     {
#       "entity": "Курдюмівка",
#       "valid": "YES",
#       "explanation": "Refers to a specific location in the Donbas region, mentioned in the text"
#     },
#     {
#       "entity": "Михайлівського Золотоверхого собору",
#       "valid": "YES",
#       "explanation": "Refers to a specific cathedral in Kyiv, mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Чернігова",
#       "valid": "YES",
#       "explanation": "Refers to the city where the victim of fraud resides"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, mentioned in the context"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, mentioned in the context"
#     }
#   ]
# }
#
# {
#   "entities": [
#     {
#       "entity": "Vintage",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the entire country of Ukraine, mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Вул. Борщагівська",
#       "valid": "YES",
#       "explanation": "Refers to a street name mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country Ukraine, mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city where the incident of food poisoning occurred"
#     },
#     {
#       "entity": "Подробиці",
#       "valid": "YES",
#       "explanation": "Refers to additional details about the incident"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "вул. Князів Острозьких",
#       "valid": "YES",
#       "explanation": "Refers to a street name mentioned in the text"
#     },
#     {
#       "entity": "№25",
#       "valid": "YES",
#       "explanation": "Refers to a bus route number mentioned in the text"
#     },
#     {
#       "entity": "38",
#       "valid": "YES",
#       "explanation": "Refers to a trolleybus route number mentioned in the text"
#     },
#     {
#       "entity": "№47",
#       "valid": "NO",
#       "explanation": "Incomplete entity, missing the full route number"
#     },
#     {
#       "entity": "№ 109",
#       "valid": "YES",
#       "explanation": "Refers to a bus route number mentioned in the text"
#     },
#     {
#       "entity": "ст",
#       "valid": "NO",
#       "explanation": "Incomplete entity, missing the full name of the metro station"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україна",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Стіні Памʼяті",
#       "valid": "YES",
#       "explanation": "Refers to a specific memorial mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Черновецьким",
#       "valid": "NO",
#       "explanation": "The entity 'Черновецьким' does not refer to a location. It seems to be a person's name."
#     },
#     {
#       "entity": "Микитасем",
#       "valid": "NO",
#       "explanation": "The entity 'Микитасем' does not refer to a location. It seems to be a person's name."
#     },
#     {
#       "entity": "Київ",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv."
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the location within Kyiv."
#     },
#     {
#       "entity": "Співочому полі",
#       "valid": "YES",
#       "explanation": "Refers to a specific location within Kyiv."
#     },
#     {
#       "entity": "Іванківської райліка",
#       "valid": "YES",
#       "explanation": "Refers to a specific location in Kyiv region."
#     },
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the Kyiv region."
#     },
#     {
#       "entity": "Білоцерківщині",
#       "valid": "YES",
#       "explanation": "Refers to the Bila Tserkva region in Kyiv region."
#     },
#     {
#       "entity": "Борисполя",
#       "valid": "YES",
#       "explanation": "Refers to the city of Boryspil in Kyiv region."
#     },
#     {
#       "entity": "Бучанському районі",
#       "valid": "YES",
#       "explanation": "Refers to a specific location within Bucha district in Kyiv region."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, mentioned in the context as the location where the business support for veterans will take place."
#     },
#     {
#       "entity": "Нацгвардії",
#       "valid": "NO",
#       "explanation": "Refers to the National Guard of Ukraine, which is a military organization rather than a specific location."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Шевченковском",
#       "valid": "YES",
#       "explanation": "Refers to a specific district in the city of Kyiv where the rocket debris caused damage and fires"
#     },
#     {
#       "entity": "Дарницком районах",
#       "valid": "YES",
#       "explanation": "Refers to a specific district in the city of Kyiv where the rocket debris caused damage and fires"
#     },
#     {
#       "entity": "Шевченкрвском районе",
#       "valid": "NO",
#       "explanation": "Typo in the entity name, should be 'Шевченковском районе'"
#     },
#     {
#       "entity": "Киеве",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv where the rocket debris caused damage"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Україні",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Євросоюзом",
#       "valid": "YES",
#       "explanation": "Refers to the European Union mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     },
#     {
#       "entity": "Євросоюзі",
#       "valid": "YES",
#       "explanation": "Refers to the European Union mentioned in the text"
#     },
#     {
#       "entity": "України",
#       "valid": "YES",
#       "explanation": "Refers to the country mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Аскольдовій могилі",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, Ascoltova Mogila, where the burial ceremony is taking place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Героїв Дніпра",
#       "valid": "YES",
#       "explanation": "Refers to a specific location mentioned in the text where a mass event is taking place"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києво-Печерської лаври",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, the Kyiv-Pechersk Lavra, which is mentioned in the text"
#     },
#     {
#       "entity": "Франції",
#       "valid": "YES",
#       "explanation": "Refers to a country, France, which is mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Київщині",
#       "valid": "YES",
#       "explanation": "Refers to the region of Kyiv, mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Мілютенка, 23а",
#       "valid": "NO",
#       "explanation": "The entity 'Мілютенка, 23а' is mentioned as the address of a building, but it is not clear if it is a location or just a reference to a specific building in the context. More information is needed to determine if it is a valid location entity."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, which is mentioned in the text as the location where the educational institutions are located."
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "вул Мостицька 4",
#       "valid": "YES",
#       "explanation": "Refers to a specific street address mentioned in the text"
#     },
#     {
#       "entity": "просп.Правди",
#       "valid": "YES",
#       "explanation": "Refers to a specific avenue mentioned in the text"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "корпусу №7",
#       "valid": "YES",
#       "explanation": "Refers to a specific building on the territory of Kyiv Polytechnic Institute"
#     },
#     {
#       "entity": "корпус №4",
#       "valid": "YES",
#       "explanation": "Refers to a specific building on the territory of Kyiv Polytechnic Institute"
#     },
#     {
#       "entity": "Києві",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv"
#     },
#     {
#       "entity": "площі знань КПІ",
#       "valid": "YES",
#       "explanation": "Refers to a specific area on the territory of Kyiv Polytechnic Institute"
#     },
#     {
#       "entity": "Караваєвих дач",
#       "valid": "NO",
#       "explanation": "Not mentioned in the context"
#     },
#     {
#       "entity": "вулицю Польова",
#       "valid": "NO",
#       "explanation": "Not mentioned in the context"
#     },
#     {
#       "entity": "вулиці академіка Янгеля",
#       "valid": "NO",
#       "explanation": "Not mentioned in the context"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Проспект Відрадний",
#       "valid": "YES",
#       "explanation": "Refers to a specific location, 'Проспект Відрадний'"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Троєщині",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Дарницька площа",
#       "valid": "YES",
#       "explanation": "Refers to a specific location mentioned in the text, which is Darnytska Square"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Києва",
#       "valid": "YES",
#       "explanation": "Refers to the city of Kyiv, mentioned in the context as the place where the police are searching for the mother and son"
#     },
#     {
#       "entity": "Чернігівську область",
#       "valid": "YES",
#       "explanation": "Refers to the Chernihiv region, mentioned in the context as the destination where the mother and son were returning to"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Хрещатику 36",
#       "valid": "",
#       "explanation": ""
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Академмістечку",
#       "valid": "YES",
#       "explanation": "Refers to a specific location where the car accident took place"
#     },
#     {
#       "entity": "Лексусі",
#       "valid": "NO",
#       "explanation": "Refers to a car brand/model, not a location entity"
#     }
#   ]
# }
# {
#   "entities": [
#     {
#       "entity": "Асканія-Нова",
#       "valid": "YES",
#       "explanation": "Refers to the name of the reserve mentioned in the text"
#     },
#     {
#       "entity": "Херсонській області",
#       "valid": "YES",
#       "explanation": "Refers to the region where the reserve is located"
#     },
#     {
#       "entity": "Урал",
#       "valid": "NO",
#       "explanation": "Refers to a type of truck, not a location entity"
#     },
#     {
#       "entity": "парку \"Асканії-Нової\"",
#       "valid": "YES",
#       "explanation": "Refers to the name of the park within the reserve"
#     }
#   ]
# }
