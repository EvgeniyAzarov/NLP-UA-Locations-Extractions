# %% [markdown]
# # Multibert, fine-tune on the ru dataset

# %%
import os
# DATA_PATH = "../data/" 
DATA_PATH = "/kaggle/input/" 
SAVE_PATH = "/kaggle/working/"

# %%
DATASETS_PATH = os.path.join(DATA_PATH, "nlp-ua-locations-extractions")

# %% [markdown]
# ## Data

# %% [markdown]
# We will use approximately the same amount of data, as for the uk multiebert fine-tuning, to reduce training time

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Load and sample data

# %%
ru_geo_dataset = pd.read_csv(os.path.join(DATASETS_PATH, 'ru_geo_dataset.csv'), converters={"loc_markers": eval})
ru_geo_dataset.shape
# Out:
# (8028840, 6)

# %% [markdown]
# In ru dataset samples are grouped by doc, from which they were taken. Since we will use only small part of dataset, we will take sample from different docs, to increase diversity in the training data. This also means that we don't need to worry about grouping samples by `doc_id` for train-val split

# %%
N_train = 100000
N_val = 10000

# %%
ru_geo_dataset_light = ru_geo_dataset.groupby('doc_id').first()\
    .sample(N_train + N_val, random_state=42).reset_index()

# %%
ru_geo_dataset_light['num_loc'] = ru_geo_dataset_light['loc_markers'].apply(len)

# %%
ru_geo_dataset_light['num_loc'].value_counts()
# Out:
# num_loc
# 1     44226
# 0     39109
# 2     19361
# 3      5614
# 4      1261
# 5       304
# 6        76
# 7        26
# 8        10
# 9         7
# 12        2
# 10        1
# 14        1
# 13        1
# 11        1
# Name: count, dtype: int64

# %%
ru_geo_dataset_light.loc[ru_geo_dataset_light['num_loc'].isin([10, 11, 12, 13, 14]), 'num_loc'] = -1

# %%
# to avoid copying the dataset, mark valid inplace (may be cruacial when using full dataset)
train_idx, val_idx = train_test_split(ru_geo_dataset_light.index, stratify=ru_geo_dataset_light['num_loc'], test_size=N_val)

# %%
ru_geo_dataset_light['is_valid'] = 0
ru_geo_dataset_light.loc[val_idx, 'is_valid'] = 1

# %%
ru_geo_dataset_light.loc[ru_geo_dataset_light['is_valid'] == 1]
# Out:
#         doc_id                                               text  \
# 26      656797  20 ноября в московском кинотеатре "Пушкинский ...
# 39      355447  Российская теннисистка Мария Шарапова, занимаю...
# 48       43590  На форме олимпийской сборной России по хоккею ...
# 50      545412  Более 20 тысяч израильтян собрались вечером в ...
# 52      215758  Актер Иван Охлобыстин назвал своего коллегу Ми...
# ...        ...                                                ...
# 109902  126580  МИД Турции вызвал посла Швеции в Анкаре после ...
# 109933  100571  Турецкая полиция опубликовала фотографию мужчи...
# 109958  655197  Американский институт кино (American Film Inst...
# 109971  517365  Конфликт вокруг анимационного телеканала "2х2"...
# 109979  250538  В казахстанском городе Жанаозен (Мангистауская...
#
#                           loc_markers            org_markers  \
# 26                                 []             [(35, 45)]
# 39                       [(127, 136)]                     []
# 48                         [(29, 35)]                     []
# 50             [(63, 73), (131, 138)]           [(161, 169)]
# 52                                 []                     []
# ...                               ...                    ...
# 109902  [(4, 10), (24, 30), (33, 39)]     [(0, 3), (54, 61)]
# 109933                     [(88, 96)]                     []
# 109958                             []  [(0, 57), (156, 163)]
# 109971                             []             [(42, 45)]
# 109979           [(23, 31), (33, 54)]           [(111, 116)]
#
#                  per_markers  sent_id  num_loc  is_valid
# 26      [(77, 83), (86, 98)]        0        0         1
# 39                [(23, 37)]        0        1         1
# 48                        []        0        1         1
# 50              [(139, 150)]        0        2         1
# 52       [(6, 21), (44, 63)]        0        0         1
# ...                      ...      ...      ...       ...
# 109902                    []        0        3         1
# 109933                    []        0        1         1
# 109958                    []        0        0         1
# 109971                    []        0        0         1
# 109979                    []        0        2         1
#
# [10000 rows x 8 columns]

# %%
ru_geo_dataset_light[['text', 'loc_markers', 'is_valid']].to_csv(os.path.join(SAVE_PATH, "ru_geo_dataset_light.csv"), index=None)

# %%
df_locations = pd.read_csv(os.path.join(SAVE_PATH, "ru_geo_dataset_light.csv"), converters={"loc_markers": eval})

# %% [markdown]
# ### Preprocess

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

# %% [markdown]
# Here we partially fixed skipping entites, which labeling doesn't align with separation to tokens. There are sill skipped entites. As we can see from the output, this happens when there is missing space before or after the entity.

# %%
import spacy

from spacy.training.iob_utils import biluo_to_iob, doc_to_biluo_tags
from tqdm.autonotebook import tqdm
tqdm.pandas()

df_locations.loc_markers = df_locations.loc_markers.apply(lambda x: [[y[0], y[1], 'LOC']  for y in x])

nlp = spacy.blank("xx")

def convert_to_conll(row):
    data = {
        "text": row['text'],
        "label": row['loc_markers']
    }
    doc = nlp(data["text"])
    ents = []
    for start, end, label in data["label"]:
        span = doc.char_span(start, end, label=label, alignment_mode='contract')
        if span is None:
            span_extended = doc.char_span(start, end, label=label, alignment_mode='expand')
            print(f"Skipping span {span_extended} expanded from {doc.text[start:end]}")
        else:
            ents.append(span)
    doc.ents = ents
    return {
        'tokens': list([t.text for t in doc]),
        'labels': list(biluo_to_iob(doc_to_biluo_tags(doc)))
    }

df_locations['conll'] = df_locations.progress_apply(convert_to_conll, axis=1)
# Out:
#   0%|          | 0/110000 [00:00<?, ?it/s]
# Skipping span США.Чиновники expanded from США
# Skipping span Москвыразработает expanded from Москвы
# Skipping span РФпришли expanded from РФ
# Skipping span вМоскве expanded from Москве
# Skipping span РФпоМоскве expanded from РФ
# Skipping span РФпоМоскве expanded from Москве
# Skipping span Скалиcтых expanded from Скали
# Skipping span РФВладимир expanded from РФ
# Skipping span вЛондоне expanded from Лондоне
# Skipping span ВМоскве expanded from Москве
# Skipping span заРоссией expanded from Россией
# Skipping span вСирию expanded from Сирию
# Skipping span ВСША expanded from США
# Skipping span вНайроби expanded from Найроби
# Skipping span ВБангкоке expanded from Бангкоке
# Skipping span ВРиге expanded from Риге
# Skipping span комитетРФ expanded from РФ
# Skipping span ВМоскве expanded from Москве
# Skipping span ВСША expanded from США
# Skipping span РФАлександр expanded from РФ
# Skipping span РФ" expanded from РФ
# Skipping span Wombwell)в expanded from Wombwell
# Skipping span воФранции expanded from Франции
# Skipping span изАйовы expanded from Айовы
# Skipping span ВМоскве expanded from Москве
# Skipping span ВКитае expanded from Китае
# Skipping span культурыРФ expanded from РФ
# Skipping span комитетРФ expanded from РФ
# Skipping span ВБолонье expanded from Болонье
# Skipping span отРоссии expanded from России
# Skipping span РФАндрей expanded from РФ
# Skipping span отКремля expanded from Кремля
# Skipping span комитетРФ expanded from РФ
# Skipping span юстицииРФ expanded from РФ
# Skipping span .РФ expanded from РФ
# Skipping span РФВладимира expanded from РФ
# Skipping span отРоссии expanded from России
# Skipping span вМоскве expanded from Москве
# Skipping span вЛондоне expanded from Лондоне
# Skipping span .РФ expanded from РФ
# Skipping span ВМоскве expanded from Москве
# Skipping span ВСтокгольме expanded from Стокгольме
# Skipping span вСНГ expanded from СНГ
# Skipping span Рафиах(Rafah expanded from Рафиах
# Skipping span Рафиах(Rafah expanded from Rafah
# Skipping span Тамбасова,5 expanded from Тамбасова
# Skipping span США.Об expanded from США
# Skipping span ВНовосибирске expanded from Новосибирске
# Skipping span РФЮрий expanded from РФ
# Skipping span изМордовии expanded from Мордовии
# Skipping span Светлогорска(Калининградская expanded from Светлогорска
# Skipping span вПодмосковье expanded from Подмосковье
# Skipping span .РФ expanded from РФ
# Skipping span ЕСсоставили expanded from ЕС
# Skipping span вМоскве expanded from Москве
# Skipping span юстицииРФ expanded from РФ
# Skipping span вПариже expanded from Париже
# Skipping span воФранции expanded from Франции
# Skipping span Дагестане,"- expanded from Дагестане
# Skipping span ВСША expanded from США
# Skipping span Динамо"(Киев expanded from Киев
# Skipping span Шахтер"(Донецк expanded from Донецк
# Skipping span вРоссии expanded from России
# Skipping span ВМоскве expanded from Москве
# Skipping span РФВладимира expanded from РФ
# Skipping span ВМоскве expanded from Москве
# Skipping span НаТриумфальной expanded from Триумфальной
# Skipping span вМоскве expanded from Москве
# Skipping span РФпроверить expanded from РФ
# Skipping span .РФ expanded from РФ
# Skipping span РФнепоступило expanded from РФ
# Skipping span вКонституцииРФ expanded from РФ
# Skipping span ВПятигорске expanded from Пятигорске
# Skipping span Москвыодобрила expanded from Москвы
# Skipping span наУкраине expanded from Украине
# Skipping span ВРоссии expanded from России
# Skipping span Лакокраска"(Лида expanded from Лида
# Skipping span Стекловолокно"(Полоцк expanded from Полоцк
# Skipping span дом"(Минск expanded from Минск
# Skipping span вСочи expanded from Сочи
# Skipping span Техаc expanded from Теха
# Skipping span ВВеликобритании expanded from Великобритании
# Skipping span РФВладимир expanded from РФ
# Skipping span тоРоссия expanded from Россия
# Skipping span вМоскве expanded from Москве
# Skipping span вДетройте expanded from Детройте
# Skipping span вМытищах expanded from Мытищах
# Skipping span вСтокгольме expanded from Стокгольме
# Skipping span вСочи expanded from Сочи
# Skipping span судаРФ expanded from РФ
# Skipping span отБурятии expanded from Бурятии
# Skipping span комитетРФ expanded from РФ
# Skipping span наКубани expanded from Кубани
# Skipping span ВРоссии expanded from России
# Skipping span Всекторе expanded from секторе
# Skipping span РФВладимир expanded from РФ
# Skipping span вСирии expanded from Сирии
# Skipping span вСочи expanded from Сочи
# Skipping span вСША expanded from США
# Skipping span РФВладимир expanded from РФ
# Skipping span ВВеликобритании expanded from Великобритании
# Skipping span ВМоскве expanded from Москве
# Skipping span вИталию expanded from Италию
# Skipping span изАфрики expanded from Африки
# Skipping span вРоссии expanded from России
# Skipping span РФГалина expanded from РФ
# Skipping span вКоломенском expanded from Коломенском
# Skipping span наКубу expanded from Кубу
# Skipping span РФВладимира expanded from РФ
# Skipping span РФАндрей expanded from РФ
# Skipping span вМоскве expanded from Москве
# Skipping span ВМоскве expanded from Москве
# Skipping span комитетРФ expanded from РФ
# Skipping span вМоскве expanded from Москве
# Skipping span ВНазрани expanded from Назрани
# Skipping span вРоссии expanded from России
# Skipping span .РФ expanded from РФ
# Skipping span вМоскве expanded from Москве
# Skipping span РФ.Проверка expanded from РФ
# Skipping span РФВладимир expanded from РФ
# Skipping span Дарвин.130-килограммовая expanded from Дарвин
# Skipping span ВИспании expanded from Испании
# Skipping span РФВладимир expanded from РФ
# Skipping span наКамчатку expanded from Камчатку
# Skipping span сСирией expanded from Сирией
# Skipping span ВАО.Строительство expanded from ВАО
# Skipping span РФВладимир expanded from РФ
# Skipping span вЛондоне expanded from Лондоне
# Skipping span вЧечне expanded from Чечне
# Skipping span вЛокарно expanded from Локарно
# Skipping span вЯпонии expanded from Японии
# Skipping span ВСети expanded from Сети
# Skipping span вМоскве expanded from Москве
# Skipping span Basilan)в expanded from Basilan)
# Skipping span вЧикаго expanded from Чикаго
# Skipping span УКРФ expanded from РФ
# Skipping span изВьетнама expanded from Вьетнама
# Skipping span вЛондоне expanded from Лондоне

# %%
label2id = {'O': 0, 'B-LOC': 1, 'I-LOC': 2}

df_locations['tokens'] = df_locations.conll.str['tokens']
df_locations['ner_tags'] = df_locations.conll.str['labels'].apply(lambda x: [label2id[t] for t in x])

df_train = df_locations[df_locations.is_valid == 0]
df_valid = df_locations[df_locations.is_valid == 1]

# %%
df_train[['tokens', 'ner_tags']].to_json(
    os.path.join(SAVE_PATH, 'train_light.json'), orient='records', lines=True)
df_valid[['tokens', 'ner_tags']].to_json(
    os.path.join(SAVE_PATH, 'valid_light.json'), orient='records', lines=True)

# %%
import datasets

# %%
from datasets import load_dataset

raw_datasets = load_dataset(
    "json",
    data_files={
        'train': os.path.join(SAVE_PATH, 'train_light.json'),
        'val': os.path.join(SAVE_PATH, 'valid_light.json'),
    },
)
# Out:
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-eb3e2ad572a9611c/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-eb3e2ad572a9611c/0.0.0/ac0ca5f5289a6cf108e706efcf040422dbbfa8e658dee6a819f20d76bb84d26b. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

label2id = {'O': 0, 'B-LOC': 1, 'I-LOC': 2}
id2label = {v: k for k, v in label2id.items()}

model = AutoModelForTokenClassification.from_pretrained(
    'bert-base-multilingual-cased',
    id2label=id2label,
    label2id=label2id,
)
tokenizer = AutoTokenizer.from_pretrained('bert-base-multilingual-cased')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer=tokenizer)

def align_labels_with_tokens(labels, word_ids):
    new_labels = []
    current_word = None
    for word_id in word_ids:
        if word_id is None:
            new_labels.append(-100)
        elif word_id != current_word:
            # Start of a new word!
            current_word = word_id
            new_labels.append(labels[word_id])
        else:
            # Same word as previous token
            label = labels[word_id]
            # If the label is B-XXX we change it to I-XXX
            if label % 2 == 1:
                label += 1
            new_labels.append(label)

    return new_labels

def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["tokens"], truncation=True, is_split_into_words=True
    )
    all_labels = examples["ner_tags"]
    new_labels = []
    for i, labels in enumerate(all_labels):
        word_ids = tokenized_inputs.word_ids(i)
        new_labels.append(align_labels_with_tokens(labels, word_ids))

    tokenized_inputs["labels"] = new_labels
    return tokenized_inputs

# %%
tokenized_datasets = raw_datasets.map(
    tokenize_and_align_labels,
    batched=True,
    remove_columns=raw_datasets["train"].column_names,
)
# Out:
#   0%|          | 0/100 [00:00<?, ?ba/s]
#   0%|          | 0/10 [00:00<?, ?ba/s]

# %%
from transformers import TrainingArguments

args = TrainingArguments(
    "multibert-ner-ru",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    num_train_epochs=3
)

# %%
from transformers import AdamW, get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup

optimizer = AdamW([
    {'params': list(model.bert.parameters()), 'lr': 1e-5},
    {'params': list(model.classifier.parameters()), 'lr': 1e-3}
])

# scheduler = get_linear_schedule_with_warmup(
#     optimizer,
#     num_warmup_steps=0.1*3*(tokenized_datasets['train'].num_rows/16),
#     num_training_steps=3*(tokenized_datasets['train'].num_rows/16)
# )
scheduler = get_cosine_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0.1*3*(tokenized_datasets['train'].num_rows/16),
    num_training_steps=3*(tokenized_datasets['train'].num_rows/16)
)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from typing import List

def metrics(y_true: List[List[str]], y_pred: List[List[str]]):
    assert len(y_true) == len(y_pred)
    tp, fp, fn = 0.0, 0.0, 0.0

    for y_true_sample, y_pred_sample in zip(y_true, y_pred):
        tp += len(set(y_true_sample) & set(y_pred_sample))
        fp += len(set(y_pred_sample) - set(y_true_sample))
        fn += len(set(y_true_sample) - set(y_pred_sample))
    
    precision = tp / (tp + fp) if tp + fp != 0 else 0.0 if tp + fn != 0.0 else 1.0
    recall = tp / (tp + fn) if tp + fn != 0 else 1.0
    f1 = 2 * precision * recall / (precision + recall) if precision + recall != 0 else 0.0

    return {
        "precision": precision,
        "recall": recall,
        "f1": f1
    }

# %%
import numpy as np

label_names = list(label2id.keys())

def compute_metrics(eval_preds):
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)

    # Remove ignored index (special tokens) and convert to labels
    true_labels = [[label_names[l] for l in label if l != -100] for label in labels]
    true_predictions = [
        [label_names[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    
    return metrics(y_true=true_predictions, y_pred=true_labels)

# %%
import wandb

try:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    api_key = user_secrets.get_secret("wandb_api")
    wandb.login(key=api_key)
    anony = None
except:
    anony = "must"
    print('If you want to use your W&B account, go to Add-ons -> Secrets and provide your W&B access token. Use the Label name as wandb_api. \nGet your W&B access token from here: https://wandb.ai/authorize')
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
from transformers import Trainer

train_sample = [tokenized_datasets['train'][i] for i in range(10)]
val_sample = [tokenized_datasets['val'][i] for i in range(10)]

trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_datasets["train"],
#     train_dataset=train_sample,
    eval_dataset=tokenized_datasets["val"],
#     eval_dataset=val_sample,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer,
    optimizers=(optimizer, scheduler)
)

# %%
trainer.train()
wandb.finish()
# Out:
# wandb: Currently logged in as: yevhenii-azarov. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.15.12 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.15.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20231028_212539-aotgpzq9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run firm-salad-6
# wandb: ⭐️ View project at https://wandb.ai/yevhenii-azarov/huggingface
# wandb: 🚀 View run at https://wandb.ai/yevhenii-azarov/huggingface/runs/aotgpzq9
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='18750' max='18750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18750/18750 49:31, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.014500</td>
#       <td>0.012330</td>
#       <td>0.993711</td>
#       <td>0.988603</td>
#       <td>0.991150</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.010100</td>
#       <td>0.010352</td>
#       <td>0.995076</td>
#       <td>0.989145</td>
#       <td>0.992102</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.007100</td>
#       <td>0.011573</td>
#       <td>0.995369</td>
#       <td>0.988909</td>
#       <td>0.992128</td>
#     </tr>
#   </tbody>
# </table><p>
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:                        eval/f1 ▁██
# wandb:                      eval/loss █▁▅
# wandb:                 eval/precision ▁▇█
# wandb:                    eval/recall ▁█▅
# wandb:                   eval/runtime █▆▁
# wandb:        eval/samples_per_second ▁▃█
# wandb:          eval/steps_per_second ▁▃█
# wandb:                    train/epoch ▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:              train/global_step ▁▁▁▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████
# wandb:            train/learning_rate ▃▅▇██████▇▇▇▇▇▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁▁▁
# wandb:                     train/loss █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:               train/total_flos ▁
# wandb:               train/train_loss ▁
# wandb:            train/train_runtime ▁
# wandb: train/train_samples_per_second ▁
# wandb:   train/train_steps_per_second ▁
# wandb:
# wandb: Run summary:
# wandb:                        eval/f1 0.99213
# wandb:                      eval/loss 0.01157
# wandb:                 eval/precision 0.99537
# wandb:                    eval/recall 0.98891
# wandb:                   eval/runtime 29.1992
# wandb:        eval/samples_per_second 342.475
# wandb:          eval/steps_per_second 21.405
# wandb:                    train/epoch 3.0
# wandb:              train/global_step 18750
# wandb:            train/learning_rate 0.0
# wandb:                     train/loss 0.0071
# wandb:               train/total_flos 1.1841235021253664e+16
# wandb:               train/train_loss 0.01773
# wandb:            train/train_runtime 3003.9441
# wandb: train/train_samples_per_second 99.869
# wandb:   train/train_steps_per_second 6.242
# wandb:
# wandb: 🚀 View run firm-salad-6 at: https://wandb.ai/yevhenii-azarov/huggingface/runs/aotgpzq9
# wandb: Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20231028_212539-aotgpzq9/logs
